# %% [markdown]
# # Chatbot Project
# Trying different models

# %%
#IMPORTS
from docx import Document
import pandas as pd

# %%
#path my docx is on -- its on the google drive
docx_file_path = 'C:\\Users\\anett\\CopyofNewFacultyOrientationResearch.docx'
doc = Document(docx_file_path)

# Create a text file to write the extracted text, this copies the text from the doc to txt
txt_file_path = 'EditedNewFacultyOrientationResearch.txt'
with open(txt_file_path, 'w', encoding='utf-8') as txt_file:
    for paragraph in doc.paragraphs:
        txt_file.write(paragraph.text + '\n')

print(f'Text extracted from {docx_file_path} and saved to {txt_file_path}')

#Local file path
txt_file_path = 'C:\\Users\\anett\\EditedNewFacultyOrientationResearch.txt'

#making the lists for the different entries
questions = []
answers = []
tags = []

# Read the text file and iterate through non-empty lines
with open(txt_file_path, 'r', encoding='utf-8') as txt_file:
    lines = [line.strip() for line in txt_file.readlines() if line.strip()]
    
    # Iterate through lines in sets of 3
    for i in range(0, len(lines), 3):
        # Check if there are enough lines left to extract a set
        # currently dependent on the three way format
        if i + 2 < len(lines):
            questions.append(lines[i])
            answers.append(lines[i + 1])
            tags.append(lines[i + 2])
        else:
            # Not enough lines, skip
            print(f"Skipping incomplete set at index {i}.")

# dataFrame from the lists of questions, answers, and tags
df = pd.DataFrame({'Question': questions, 'Answer': answers, 'Tag': tags})
df.head()
# Out:
# Text extracted from C:\Users\anett\CopyofNewFacultyOrientationResearch.docx and saved to EditedNewFacultyOrientationResearch.txt
#                                             Question  \
# 0  I would like to submit a proposal, how do I ge...
# 1   How soon should I start my Cayuse routing sheet?
# 2                 What are IIT’s internal deadlines?
# 3  How will I know who my assigned research admin...
# 4  OSRP only handles federally sponsored projects...
#
#                                               Answer       Tag
# 0  Please start a routing sheet (SP proposal) in ...  proposal
# 1  Please start the first page, General tab, of t...     other
# 2  The administrative portions of the proposal (b...     other
# 3  After you start your routing sheet, OSRP will ...  research
# 4  No. OSRP handles all sponsored projects for th...     other

# %%
#copying the dataframe, so I do not mess up the first one
df_copy = df.copy()

# Adding another column of similar questions to the dataframe
new_column_values = [
    "How do I initiate the process of submitting a proposal?",
    "When should I begin filling out my Cayuse routing sheet?",
    "What are the internal deadlines set by IIT?",
    "How can I find out the identity of my assigned research administrator?",
    "Is it accurate to say that OSRP exclusively handles federally sponsored projects?",
    "As a faculty member, am I authorized to enter into legally binding agreements on behalf of Illinois Tech?",
    "I've been requested by an industrial partner to sign a non-disclosure agreement (NDA). What steps should I take?",
    "Could you explain what indirect costs (also known as facilities and administrative or F&A costs) entail?",
    "What are the indirect cost rates applicable to Illinois Tech?",
    "Am I allowed to negotiate my own indirect cost rate for my proposal?",
    "If I'm submitting a proposal to a foundation that prohibits indirect costs, or imposes a cap lower than the established IIT rates, how should I proceed?",
    "Where can I access additional guidance on preparing my proposal?",
    "Where can I find further information on the sponsored research policies of Illinois Tech?"
]

# Add the new column to the DataFrame
df['similarQ1'] = new_column_values
df.head()
# Out:
#                                             Question  \
# 0  I would like to submit a proposal, how do I ge...
# 1   How soon should I start my Cayuse routing sheet?
# 2                 What are IIT’s internal deadlines?
# 3  How will I know who my assigned research admin...
# 4  OSRP only handles federally sponsored projects...
#
#                                               Answer       Tag  \
# 0  Please start a routing sheet (SP proposal) in ...  proposal
# 1  Please start the first page, General tab, of t...     other
# 2  The administrative portions of the proposal (b...     other
# 3  After you start your routing sheet, OSRP will ...  research
# 4  No. OSRP handles all sponsored projects for th...     other
#
#                                            similarQ1
# 0  How do I initiate the process of submitting a ...
# 1  When should I begin filling out my Cayuse rout...
# 2        What are the internal deadlines set by IIT?
# 3  How can I find out the identity of my assigned...
# 4  Is it accurate to say that OSRP exclusively ha...

# %% [markdown]
# I repeated this three more times if you dont care to look at it.

# %%
new_column_values = [
    "How do I begin the process of drafting and submitting a proposal?",
    "When is the optimal time to start completing my Cayuse routing sheet?",
    "What are the internal deadlines established by IIT that I need to be aware of?",
    "How can I determine the identity of the research administrator assigned to me?",
    "Is it correct to assume that OSRP exclusively manages projects funded by federal entities?",
    "As a faculty member, do I possess the authority to legally commit Illinois Tech to agreements?",
    "A corporate partner has asked me to sign a non-disclosure agreement (NDA). What are the recommended steps for handling this request?",
    "Can you provide an explanation of what is encompassed by indirect costs, also referred to as facilities and administrative or F&A costs?",
    "What are the prevailing indirect cost rates applicable to Illinois Tech's sponsored projects?",
    "Do I have the ability to negotiate my own indirect cost rate when submitting a proposal?",
    "In the event that a foundation prohibits indirect costs or imposes a cap lower than the established IIT rates, what actions should I take?",
    "Where can I find additional resources for guidance on preparing my proposal?",
    "Where can I access comprehensive information regarding Illinois Tech's policies on sponsored research?"
]

# Add the new column to the DataFrame
df['similarQ2'] = new_column_values
df.head()
# Out:
#                                             Question  \
# 0  I would like to submit a proposal, how do I ge...
# 1   How soon should I start my Cayuse routing sheet?
# 2                 What are IIT’s internal deadlines?
# 3  How will I know who my assigned research admin...
# 4  OSRP only handles federally sponsored projects...
#
#                                               Answer       Tag  \
# 0  Please start a routing sheet (SP proposal) in ...  proposal
# 1  Please start the first page, General tab, of t...     other
# 2  The administrative portions of the proposal (b...     other
# 3  After you start your routing sheet, OSRP will ...  research
# 4  No. OSRP handles all sponsored projects for th...     other
#
#                                            similarQ1  \
# 0  How do I initiate the process of submitting a ...
# 1  When should I begin filling out my Cayuse rout...
# 2        What are the internal deadlines set by IIT?
# 3  How can I find out the identity of my assigned...
# 4  Is it accurate to say that OSRP exclusively ha...
#
#                                            similarQ2
# 0  How do I begin the process of drafting and sub...
# 1  When is the optimal time to start completing m...
# 2  What are the internal deadlines established by...
# 3  How can I determine the identity of the resear...
# 4  Is it correct to assume that OSRP exclusively ...

# %%
new_column_values = [
    "How can I get started with drafting and submitting a proposal?",
    "When should I aim to start completing my Cayuse routing sheet?",
    "What are the internal deadlines set by IIT that I should be mindful of?",
    "How do I find out who my assigned research administrator is?",
    "Does OSRP exclusively handle projects funded by federal sponsors?",
    "As a faculty member, am I empowered to legally commit Illinois Tech to agreements?",
    "I've been asked by a corporate partner to sign an NDA. What steps should I take?",
    "Can you explain the concept of indirect costs, also known as facilities and administrative or F&A costs?",
    "What are the current indirect cost rates applicable to sponsored projects at Illinois Tech?",
    "Do I have the ability to negotiate my own indirect cost rate for my proposal?",
    "If a foundation disallows indirect costs or imposes a rate lower than IIT's, how should I proceed?",
    "Where can I find additional guidance on preparing my proposal?",
    "Where can I locate comprehensive information about Illinois Tech's sponsored research policies?"
]

# Add the new column to the DataFrame
df['similarQ3'] = new_column_values
df.head()
# Out:
#                                             Question  \
# 0  I would like to submit a proposal, how do I ge...
# 1   How soon should I start my Cayuse routing sheet?
# 2                 What are IIT’s internal deadlines?
# 3  How will I know who my assigned research admin...
# 4  OSRP only handles federally sponsored projects...
#
#                                               Answer       Tag  \
# 0  Please start a routing sheet (SP proposal) in ...  proposal
# 1  Please start the first page, General tab, of t...     other
# 2  The administrative portions of the proposal (b...     other
# 3  After you start your routing sheet, OSRP will ...  research
# 4  No. OSRP handles all sponsored projects for th...     other
#
#                                            similarQ1  \
# 0  How do I initiate the process of submitting a ...
# 1  When should I begin filling out my Cayuse rout...
# 2        What are the internal deadlines set by IIT?
# 3  How can I find out the identity of my assigned...
# 4  Is it accurate to say that OSRP exclusively ha...
#
#                                            similarQ2  \
# 0  How do I begin the process of drafting and sub...
# 1  When is the optimal time to start completing m...
# 2  What are the internal deadlines established by...
# 3  How can I determine the identity of the resear...
# 4  Is it correct to assume that OSRP exclusively ...
#
#                                            similarQ3
# 0  How can I get started with drafting and submit...
# 1  When should I aim to start completing my Cayus...
# 2  What are the internal deadlines set by IIT tha...
# 3  How do I find out who my assigned research adm...
# 4  Does OSRP exclusively handle projects funded b...

# %%
new_column_values = [
    "How do I start the process of initiating and submitting a proposal?",
    "When is the ideal time to begin filling out my Cayuse routing sheet?",
    "What are the internal deadlines enforced by IIT that I need to adhere to?",
    "How can I discover the identity of my designated research administrator?",
    "Is it accurate to assert that OSRP solely manages federally sponsored projects?",
    "As a faculty member, do I possess the authority to legally bind Illinois Tech?",
    "A corporate partner has requested me to sign a non-disclosure agreement (NDA). What steps should I take?",
    "Could you provide a breakdown of indirect costs, also referred to as facilities and administrative or F&A costs?",
    "What are the current indirect cost rates applicable at Illinois Tech?",
    "Can I negotiate my own indirect cost rate for my proposal?",
    "If I'm submitting a proposal to a foundation that prohibits or limits indirect costs, how should I proceed?",
    "Where can I find additional resources on how to prepare my proposal?",
    "Where can I find more information on Illinois Tech's sponsored research policies?"
]

# Add the new column to the DataFrame
df['similarQ4'] = new_column_values
df.head()
# Out:
#                                             Question  \
# 0  I would like to submit a proposal, how do I ge...
# 1   How soon should I start my Cayuse routing sheet?
# 2                 What are IIT’s internal deadlines?
# 3  How will I know who my assigned research admin...
# 4  OSRP only handles federally sponsored projects...
#
#                                               Answer       Tag  \
# 0  Please start a routing sheet (SP proposal) in ...  proposal
# 1  Please start the first page, General tab, of t...     other
# 2  The administrative portions of the proposal (b...     other
# 3  After you start your routing sheet, OSRP will ...  research
# 4  No. OSRP handles all sponsored projects for th...     other
#
#                                            similarQ1  \
# 0  How do I initiate the process of submitting a ...
# 1  When should I begin filling out my Cayuse rout...
# 2        What are the internal deadlines set by IIT?
# 3  How can I find out the identity of my assigned...
# 4  Is it accurate to say that OSRP exclusively ha...
#
#                                            similarQ2  \
# 0  How do I begin the process of drafting and sub...
# 1  When is the optimal time to start completing m...
# 2  What are the internal deadlines established by...
# 3  How can I determine the identity of the resear...
# 4  Is it correct to assume that OSRP exclusively ...
#
#                                            similarQ3  \
# 0  How can I get started with drafting and submit...
# 1  When should I aim to start completing my Cayus...
# 2  What are the internal deadlines set by IIT tha...
# 3  How do I find out who my assigned research adm...
# 4  Does OSRP exclusively handle projects funded b...
#
#                                            similarQ4
# 0  How do I start the process of initiating and s...
# 1  When is the ideal time to begin filling out my...
# 2  What are the internal deadlines enforced by II...
# 3  How can I discover the identity of my designat...
# 4  Is it accurate to assert that OSRP solely mana...

# %% [markdown]
# ## Figuring out which model has the best similarity scores

# %% [markdown]
# Models we should try:
# distillBert - anette found (metrics of this model?)
# hugging face bge-large-en-v1.5 - from prof
# SFR
#
# He gave us a leaderboard and we can look for other ones
#
# Implement 1 and 8 on the leader board for Fri.
# Research other small pretrained, embedding models (choose 7 models we want to try)
# Give out clear tags
# draw out full thing from whiteboard for Fri.
#
# Future work:
# @anette give cs team dataframe
# compare all 7 models against each other for best similarity scores(accuracy/match to original question), gpu usage, and speed
# figure out threshold
